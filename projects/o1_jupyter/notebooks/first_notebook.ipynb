# %% [markdown]
# # First Notebook (Goal - complete course by 22nd December)

# %%
print("Hello the world!")
# Out:
# Hello the world!

# %%
a = 5
b = 6

# %%
print(a + b)
# Out:
# 11

# %%
a = 7

# %%
print(a + b)
# Out:
# 13

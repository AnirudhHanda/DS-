# %%
str = "Homi"
print(type(str))
# Out:
# <class 'str'>

# %%
## This is a single Line comment

# %%
print("Hello world") # This line will print Hello world
# Out:
# Hello world

# %%
a = "54"

# %%
b = "5"

# %%
print(a + b)
# Out:
# 545

# %% [markdown]
# ## Type Casting

# %%
print(int(a) + int(b))
# Out:
# 59

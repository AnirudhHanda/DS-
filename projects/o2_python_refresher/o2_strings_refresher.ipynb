# %% [markdown]
# ## String Slicing

# %%
s="codewithharry"

# %%
len(s)
# Out:
# 13

# %%
s[0:5]
# Out:
# 'codew'

# %%
s[1:-1]
# Out:
# 'odewithharr'

# %%
s[-12:-1]
# Out:
# 'odewithharr'

# %% [markdown]
# - Just add len(str) to the -ve index value -> to get its positive value
